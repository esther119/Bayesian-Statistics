# %% [markdown]
# <a href="https://colab.research.google.com/github/esther119/Bayesian-Statistics/blob/main/CS146_Session_16_Factor_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

alpha = 1
beta = 1
N = 10



for player in range(1,4):
  pi = stats.beta.rvs(a=alpha, b=beta, size=10) #Sampling from beta distribution 
  for games in range(1,5): 
    k= stats.binom.rvs(N, pi)
  print('player', player, k)
# Out:
# player 1 [8 8 9 9 2 7 3 4 4 1]
# player 2 [ 5  4  0  3  0  5  4 10  2  1]
# player 3 [9 9 6 5 6 1 8 1 6 8]

# %% [markdown]
# The matrix represents the numbers of success that play 1, 2, 3 have if they attempt 10 times in every games.
